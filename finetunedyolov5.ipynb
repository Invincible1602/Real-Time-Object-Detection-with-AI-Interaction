# %% [markdown]
# <a href="https://colab.research.google.com/github/Invincible1602/Real-Time-Object-Detection-with-AI-Interaction/blob/main/finetunedyolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -L "https://universe.roboflow.com/ds/bNkpK30diY?key=dICa3LvZ1g" > roboflow.zip;
# !unzip roboflow.zip
# !rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/ci_img_989_jpg.rf.22a84a0002100864d5126e0c634cc3b4.jpg
#  extracting: train/images/ci_img_98_jpg.rf.8a192a6f184032d07265f7de6e3c3af8.jpg
#  extracting: train/images/ci_img_990_jpg.rf.845becb39ba87893c8f043d1ec8c49ac.jpg
#  extracting: train/images/ci_img_991_jpg.rf.c5a6f6d7b05e2fc5351f16cba53a6159.jpg
#  extracting: train/images/ci_img_992_jpg.rf.60ce947cb85a1a00e7877af334cf7067.jpg
#  extracting: train/images/ci_img_993_jpg.rf.bd0841be50b8741ed5aa414f295ec33b.jpg
#  extracting: train/images/ci_img_994_jpg.rf.049cefbc0a9c53d84bf4d6d45ea17e39.jpg
#  extracting: train/images/ci_img_996_jpg.rf.c4edcd7d0a92e46ba31bbdaac0c03299.jpg
#  extracting: train/images/ci_img_997_jpg.rf.9f19f7bde7d0a2bc6c6d84df806a39c2.jpg
#  extracting: train/images/ci_img_998_jpg.rf.81a71663158572946aaa141bdea47e7d.jpg
#  extracting: train/images/ci_img_999_jpg.rf.bd53674fc596a5546461e68afaee9ebf.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (e.g., YOLOv8n or YOLO11n)
model = YOLO("/content/yolov5n.pt")

# Train the model on your custom dataset
results = model.train(data="data.yaml", epochs=100, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# PRO TIP 💡 Replace 'model=/content/yolov5n.pt' with new 'model=/content/yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 349MB/s]
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
